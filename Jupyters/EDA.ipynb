# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np
# Recreate the EDA plots safely
import matplotlib.pyplot as plt
import seaborn as sns

# %%
path = r"/content/drive/MyDrive/UTSA/UTSA - ITESM - FairHousing/Data/"

# %%
census_data = pd.read_csv(path + "CENSUS USA/census_data.csv")
census_data
# Out:
#              GEOID                             Census Tract Name  \
# 0      48001950100     Census Tract 9501; Anderson County; Texas
# 1      48001950401  Census Tract 9504.01; Anderson County; Texas
# 2      48001950402  Census Tract 9504.02; Anderson County; Texas
# 3      48001950500     Census Tract 9505; Anderson County; Texas
# 4      48001950600     Census Tract 9506; Anderson County; Texas
# ...            ...                                           ...
# 59169  48461950100        Census Tract 9501, Upton County, Texas
# 59170  48021950100      Census Tract 9501, Bastrop County, Texas
# 59171  48065950100       Census Tract 9501, Carson County, Texas
# 59172  48065950200       Census Tract 9502, Carson County, Texas
# 59173  48155950100        Census Tract 9501, Foard County, Texas
#
#        Total Population  Black or African American (%)  \
# 0                  5359                            6.0
# 1                  4196                           34.6
# ...

# %%
austin =  pd.read_csv(path + "Eviction Tracking System/austin_monthly_2020_2021.csv")
austin
# Out:
#           type   GEOID racial_majority    month  filings_2020  filings_avg  \
# 0     Zip Code   73301           Other  01/2020             0          0.0
# 1     Zip Code   73301           Other  02/2020             0          0.0
# 2     Zip Code   73301           Other  03/2020             0          0.0
# 3     Zip Code   73301           Other  04/2020             0          0.0
# 4     Zip Code   73301           Other  05/2020             0          0.0
# ...        ...     ...             ...      ...           ...          ...
# 6159  Zip Code  sealed             NaN  03/2025          1235        901.5
# 6160  Zip Code  sealed             NaN  04/2025          1112        817.5
# 6161  Zip Code  sealed             NaN  05/2025          1140        915.0
# 6162  Zip Code  sealed             NaN  06/2025          1204        952.0
# 6163  Zip Code  sealed             NaN  07/2025           102         91.5
#
#       filings_avg_prepandemic_baseline last_updated
# ...

# %%
dallas =  pd.read_csv(path + "Eviction Tracking System/dallas_monthly_2020_2021.csv")
dallas
# Out:
#                type        GEOID racial_majority    month  filings_2020  \
# 0      Census Tract  48113000100           White  01/2020             3
# 1      Census Tract  48113000100           White  02/2020             3
# 2      Census Tract  48113000100           White  03/2020             5
# 3      Census Tract  48113000100           White  04/2020             1
# 4      Census Tract  48113000100           White  05/2020             0
# ...             ...          ...             ...      ...           ...
# 41339  Census Tract       sealed             NaN  12/2024             8
# 41340  Census Tract       sealed             NaN  01/2025            15
# 41341  Census Tract       sealed             NaN  02/2025             5
# 41342  Census Tract       sealed             NaN  03/2025             1
# 41343  Census Tract       sealed             NaN  04/2025             0
#
#        filings_avg  filings_avg_prepandemic_baseline last_updated
# ...

# %%
houston =  pd.read_csv(path + "Eviction Tracking System/houston_monthly_2020_2021.csv")
houston
# Out:
# /tmp/ipython-input-7-2996083138.py:1: DtypeWarning: Columns (1) have mixed types. Specify dtype option on import or set low_memory=False.
#   houston =  pd.read_csv(path + "Eviction Tracking System/houston_monthly_2020_2021.csv")
#                type        GEOID racial_majority    month  filings_2020  \
# 0      Census Tract  48167720100           White  01/2020             1
# 1      Census Tract  48167720100           White  02/2020             1
# 2      Census Tract  48167720100           White  03/2020             0
# 3      Census Tract  48167720100           White  04/2020             0
# 4      Census Tract  48167720100           White  05/2020             0
# ...             ...          ...             ...      ...           ...
# 81668  Census Tract       sealed             NaN  03/2025            40
# 81669  Census Tract       sealed             NaN  04/2025            37
# 81670  Census Tract       sealed             NaN  05/2025            45
# ...

# %%
cities_df = pd.concat([austin, dallas, houston], ignore_index=True)
filtered_data = cities_df.loc[cities_df["GEOID"] != "sealed"]
filtered_data.to_csv("/content/drive/MyDrive/UTSA/UTSA - ITESM - FairHousing/Data/Full_Data/eviction_month_2020-2021.csv", index=False)
filtered_data.head()
# Out:
#        type  GEOID racial_majority    month  filings_2020  filings_avg  \
# 0  Zip Code  73301           Other  01/2020             0          0.0
# 1  Zip Code  73301           Other  02/2020             0          0.0
# 2  Zip Code  73301           Other  03/2020             0          0.0
# 3  Zip Code  73301           Other  04/2020             0          0.0
# 4  Zip Code  73301           Other  05/2020             0          0.0
#
#    filings_avg_prepandemic_baseline last_updated
# 0                               0.0          NaN
# 1                               0.0          NaN
# 2                               0.0          NaN
# 3                               0.0          NaN
# 4                               0.0          NaN

# %%
df_merged = pd.merge(filtered_data, census_data, on="GEOID")
print(df_merged.shape)
df_merged.head()
# Out:
# (449134, 27)
#            type        GEOID racial_majority    month  filings_2020  \
# 0  Census Tract  48167720100           White  01/2020             1
# 1  Census Tract  48167720100           White  01/2020             1
# 2  Census Tract  48167720100           White  01/2020             1
# 3  Census Tract  48167720100           White  01/2020             1
# 4  Census Tract  48167720100           White  01/2020             1
#
#    filings_avg  filings_avg_prepandemic_baseline last_updated  \
# 0          0.5                               1.0          NaN
# 1          0.5                               1.0          NaN
# 2          0.5                               1.0          NaN
# 3          0.5                               1.0          NaN
# 4          0.5                               1.0          NaN
#
#                             Census Tract Name  Total Population  ...  \
# 0  Census Tract 7201; Galveston County; Texas              5707  ...
# ...
